# %%
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.0.0

# %%
mnist = tf.keras.datasets.mnist

# %%
(tranies_img, tranies_label),(test_img, test_label) = mnist.load_data()

# %%
tranies_img = tranies_img / 255.0
tranies_label = tranies_label / 255.0

# %%
model = tf.keras.models.Sequential([tf.keras.layers.Flatten(),
                                     tf.keras.layers.Dense(512, activation = tf.nn.relu),
                                     tf.keras.layers.Dense(10, activation = tf.nn.softmax)])

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(),
             loss = 'sparse_categorical_crossentropy',
             metrics = ['accuracy'])

# %%
model.fit(tranies_img, tranies_label, epochs = 10)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 12s 207us/sample - loss: 0.0018 - accuracy: 0.0987
# Epoch 2/10
# 60000/60000 [==============================] - 11s 182us/sample - loss: 2.4036e-07 - accuracy: 0.0987
# Epoch 3/10
# 60000/60000 [==============================] - 11s 182us/sample - loss: 5.1288e-08 - accuracy: 0.0987
# Epoch 4/10
# 60000/60000 [==============================] - 11s 181us/sample - loss: 1.6478e-08 - accuracy: 0.0987
# Epoch 5/10
# 60000/60000 [==============================] - 11s 182us/sample - loss: 6.4968e-09 - accuracy: 0.0987
# Epoch 6/10
# 60000/60000 [==============================] - 11s 183us/sample - loss: 2.8352e-09 - accuracy: 0.0987
# Epoch 7/10
# 60000/60000 [==============================] - 11s 184us/sample - loss: 1.2517e-09 - accuracy: 0.0987
# Epoch 8/10
# 60000/60000 [==============================] - 11s 184us/sample - loss: 6.7949e-10 - accuracy: 0.0987
# Epoch 9/10
# 60000/60000 [==============================] - 11s 186us/sample - loss: 3.8346e-10 - accuracy: 0.0987
# Epoch 10/10
# 60000/60000 [==============================] - 11s 182us/sample - loss: 2.3643e-10 - accuracy: 0.0987

# %%
model.evaluate(test_img, test_label)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [11617.428590625, 0.098]
