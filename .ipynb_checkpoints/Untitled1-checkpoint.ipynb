# %%
import pandas as pd
from tensorflow.keras.utils import to_categorical
from sklearn import preprocessing as pp
from sklearn.utils import shuffle
enc = pp.LabelEncoder()
# LOAD DATASET
sonar_df = pd.read_csv("dataset/sonar.csv", header=None)
display(sonar_df.shape)
#LABEL ENCODING
sonar_df.iloc[:,60] = enc.fit_transform(y=sonar_df.iloc[:,60])
#SHUFFLE DATASET
# display(sonar_df)
sonar_df = sonar_df.sample(frac=1)
# display(sonar_df)
# = shuffle(sonar_df)
# split training (70) validation (10) and test (20) %
train_size = int(len(sonar_df) * .7)
valid_size = int(len(sonar_df) * .1)
test_size = int(len(sonar_df) * .2)
df_train = sonar_df.iloc[:train_size,:59]
df_valid = sonar_df.iloc[train_size:train_size + valid_size,:59]
df_test =  sonar_df.iloc[train_size + valid_size:-1,:59]
# df_train.shape
# df_valid.shape
# df_test.shape
df_train

df_train=sonar_df.iloc[:144,:60]
df_train_label = sonar_df.iloc[:144, 60]
train_data = df_train.to_numpy()
train_labels = df_train_label.to_numpy()
one_hot_trrain_labels = to_categorical(train_labels)


train_data = sonar_df.iloc[:144,:60].values
df.sample(frac=1)

# 4) Split inputs and labels (output)
# 5) label one hot coding
# 6) fit model without validation (compare training and testing acuracies)
# 7) fit model wit validation (with history)
# 8) create graph
# 9) Introduce k-fold, as data is limited
# 10) tune nework accuracy by ephoc numbers, change of optimizer,
# Out:
# (208, 61)
#      0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 68   0.0216  0.0215  0.0273  0.0139  0.0357  0.0785  0.0906  0.0908  0.1151
# 192  0.0203  0.0121  0.0380  0.0128  0.0537  0.0874  0.1021  0.0852  0.1136
# 104  0.0116  0.0179  0.0449  0.1096  0.1913  0.0924  0.0761  0.1092  0.0757
# 18   0.0126  0.0149  0.0641  0.1732  0.2565  0.2559  0.2947  0.4110  0.4983
# 146  0.0654  0.0649  0.0737  0.1132  0.2482  0.1257  0.1797  0.0989  0.2460
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 116  0.0228  0.0106  0.0130  0.0842  0.1117  0.1506  0.1776  0.0997  0.1428
# 30   0.0084  0.0153  0.0291  0.0432  0.0951  0.0752  0.0414  0.0259  0.0692
# 126  0.0209  0.0261  0.0120  0.0768  0.1064  0.1680  0.3016  0.3460  0.3314
# 91   0.0260  0.0192  0.0254  0.0061  0.0352  0.0701  0.1263  0.1080  0.1523
# 142  0.0516  0.0944  0.0622  0.0415  0.0995  0.2431  0.1777  0.2018  0.2611
#
#      0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  \
# 68   0.0973  ...  0.0140  0.0044  0.0052  0.0073  0.0021  0.0047  0.0024
# 192  0.1747  ...  0.0134  0.0094  0.0047  0.0045  0.0042  0.0028  0.0036
# 104  0.1006  ...  0.0163  0.0099  0.0084  0.0270  0.0277  0.0097  0.0054
# 18   0.5920  ...  0.0092  0.0035  0.0098  0.0121  0.0006  0.0181  0.0094
# 146  0.3422  ...  0.0210  0.0361  0.0239  0.0447  0.0394  0.0355  0.0440
# ..      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 116  0.2227  ...  0.0098  0.0178  0.0077  0.0074  0.0095  0.0055  0.0045
# 30   0.1753  ...  0.0236  0.0114  0.0136  0.0117  0.0060  0.0058  0.0031
# 126  0.4125  ...  0.0057  0.0159  0.0085  0.0372  0.0101  0.0127  0.0288
# 91   0.1630  ...  0.0118  0.0120  0.0051  0.0070  0.0015  0.0035  0.0008
# 142  0.1294  ...  0.0432  0.0274  0.0152  0.0120  0.0129  0.0020  0.0109
#
#      0.0090  0.0032  R
# 68   0.0009  0.0017  R
# 192  0.0013  0.0016  M
# 104  0.0148  0.0092  M
# 18   0.0116  0.0063  R
# 146  0.0243  0.0098  M
# ..      ...     ... ..
# 116  0.0063  0.0039  M
# 30   0.0072  0.0045  R
# 126  0.0129  0.0023  M
# 91   0.0044  0.0077  R
# 142  0.0074  0.0078  M
#
# [207 rows x 61 columns]
