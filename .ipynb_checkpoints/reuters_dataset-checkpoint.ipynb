# %% [markdown]
# # WITH EPOCHS=20

# %%
from tensorflow.keras.datasets import reuters

(train_data, train_labels), (test_data, test_labels) = reuters.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2113536/2110848 [==============================] - 2s 1us/step

# %%
import numpy as np

def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.
    return results

x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

# %%
from tensorflow.keras.utils import to_categorical

one_hot_train_labels = to_categorical(train_labels)
one_hot_test_labels = to_categorical(test_labels)

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(46, activation='softmax'))

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
x_val = x_train[:1000]
partial_x_train = x_train[1000:]

y_val = one_hot_train_labels[:1000]
partial_y_train = one_hot_train_labels[1000:]

# %%
history = model.fit(partial_x_train, partial_y_train, epochs=20, batch_size=512, validation_data=(x_val, y_val))
# Out:
# Train on 7982 samples, validate on 1000 samples
# Epoch 1/20
# 7982/7982 [==============================] - 2s 235us/sample - loss: 2.6140 - accuracy: 0.5376 - val_loss: 1.7630 - val_accuracy: 0.6500
# Epoch 2/20
# 7982/7982 [==============================] - 1s 92us/sample - loss: 1.4314 - accuracy: 0.7023 - val_loss: 1.3087 - val_accuracy: 0.7080
# Epoch 3/20
# 7982/7982 [==============================] - 1s 95us/sample - loss: 1.0558 - accuracy: 0.7720 - val_loss: 1.1340 - val_accuracy: 0.7620
# Epoch 4/20
# 7982/7982 [==============================] - 1s 92us/sample - loss: 0.8347 - accuracy: 0.8236 - val_loss: 1.0507 - val_accuracy: 0.7600
# Epoch 5/20
# 7982/7982 [==============================] - 1s 97us/sample - loss: 0.6652 - accuracy: 0.8643 - val_loss: 0.9925 - val_accuracy: 0.7790
# Epoch 6/20
# 7982/7982 [==============================] - 1s 97us/sample - loss: 0.5331 - accuracy: 0.8913 - val_loss: 0.9310 - val_accuracy: 0.8070
# Epoch 7/20
# 7982/7982 [==============================] - 1s 94us/sample - loss: 0.4249 - accuracy: 0.9158 - val_loss: 0.9130 - val_accuracy: 0.8130
# Epoch 8/20
# 7982/7982 [==============================] - 1s 96us/sample - loss: 0.3465 - accuracy: 0.9298 - val_loss: 0.9203 - val_accuracy: 0.8100
# Epoch 9/20
# 7982/7982 [==============================] - 1s 95us/sample - loss: 0.2864 - accuracy: 0.9419 - val_loss: 0.9250 - val_accuracy: 0.8200
# Epoch 10/20
# 7982/7982 [==============================] - 1s 93us/sample - loss: 0.2441 - accuracy: 0.9445 - val_loss: 0.9238 - val_accuracy: 0.8080
# Epoch 11/20
# 7982/7982 [==============================] - 1s 93us/sample - loss: 0.2069 - accuracy: 0.9495 - val_loss: 0.9413 - val_accuracy: 0.8040
# Epoch 12/20
# 7982/7982 [==============================] - 1s 95us/sample - loss: 0.1873 - accuracy: 0.9520 - val_loss: 0.9390 - val_accuracy: 0.8110
# Epoch 13/20
# 7982/7982 [==============================] - 1s 95us/sample - loss: 0.1672 - accuracy: 0.9524 - val_loss: 0.9542 - val_accuracy: 0.8090
# Epoch 14/20
# 7982/7982 [==============================] - 1s 93us/sample - loss: 0.1507 - accuracy: 0.9548 - val_loss: 0.9661 - val_accuracy: 0.8070
# Epoch 15/20
# 7982/7982 [==============================] - 1s 94us/sample - loss: 0.1371 - accuracy: 0.9564 - val_loss: 0.9840 - val_accuracy: 0.8080
# Epoch 16/20
# 7982/7982 [==============================] - 1s 94us/sample - loss: 0.1293 - accuracy: 0.9572 - val_loss: 1.0265 - val_accuracy: 0.8030
# Epoch 17/20
# 7982/7982 [==============================] - 1s 94us/sample - loss: 0.1285 - accuracy: 0.9563 - val_loss: 1.0235 - val_accuracy: 0.8080
# Epoch 18/20
# 7982/7982 [==============================] - 1s 94us/sample - loss: 0.1179 - accuracy: 0.9579 - val_loss: 1.0367 - val_accuracy: 0.8160
# Epoch 19/20
# 7982/7982 [==============================] - 1s 95us/sample - loss: 0.1171 - accuracy: 0.9567 - val_loss: 1.0803 - val_accuracy: 0.8070
# Epoch 20/20
# 7982/7982 [==============================] - 1s 104us/sample - loss: 0.1133 - accuracy: 0.9590 - val_loss: 1.1303 - val_accuracy: 0.8030

# %%
import matplotlib.pyplot as plt

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')

plt.title('Training and validation loss')

plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.legend()
plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')

plt.title('Training and validation accuracy')

plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.legend()
plt.show()

# %% [markdown]
# # WITH EPOCHS=9

# %%
model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(46, activation='softmax'))

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(partial_x_train, partial_y_train, epochs=9, batch_size=512, validation_data=(x_val, y_val))

results = model.evaluate(x_test, one_hot_test_labels)
# Out:
# Train on 7982 samples, validate on 1000 samples
# Epoch 1/9
# 7982/7982 [==============================] - 2s 205us/sample - loss: 2.7420 - accuracy: 0.4617 - val_loss: 1.8447 - val_accuracy: 0.6300
# Epoch 2/9
# 7982/7982 [==============================] - 1s 94us/sample - loss: 1.4837 - accuracy: 0.7032 - val_loss: 1.3385 - val_accuracy: 0.7180
# Epoch 3/9
# 7982/7982 [==============================] - 1s 94us/sample - loss: 1.0893 - accuracy: 0.7749 - val_loss: 1.1461 - val_accuracy: 0.7630
# Epoch 4/9
# 7982/7982 [==============================] - 1s 94us/sample - loss: 0.8626 - accuracy: 0.8236 - val_loss: 1.0487 - val_accuracy: 0.7830
# Epoch 5/9
# 7982/7982 [==============================] - 1s 93us/sample - loss: 0.6986 - accuracy: 0.8548 - val_loss: 0.9731 - val_accuracy: 0.7960
# Epoch 6/9
# 7982/7982 [==============================] - 1s 95us/sample - loss: 0.5602 - accuracy: 0.8839 - val_loss: 0.9308 - val_accuracy: 0.8110
# Epoch 7/9
# 7982/7982 [==============================] - 1s 94us/sample - loss: 0.4516 - accuracy: 0.9074 - val_loss: 0.8828 - val_accuracy: 0.8260
# Epoch 8/9
# 7982/7982 [==============================] - 1s 95us/sample - loss: 0.3668 - accuracy: 0.9246 - val_loss: 0.8857 - val_accuracy: 0.8160
# Epoch 9/9
# 7982/7982 [==============================] - 1s 92us/sample - loss: 0.3021 - accuracy: 0.9355 - val_loss: 0.8956 - val_accuracy: 0.8210
# 2246/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...

# %%
print(results)
# Out:
# [0.9863266768672057, 0.79162955]

# %%
predictions = model.predict(x_test)

# %%
predictions[0].shape
# Out:
# (46,)

# %%
np.sum(predictions[0])
# Out:
# 1.0000001

# %%
print(type(predictions[0]))
# Out:
# <class 'numpy.ndarray'>

# %%
np.argmax(predictions[0])
# Out:
# 3
